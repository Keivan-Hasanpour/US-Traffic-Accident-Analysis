# %% [markdown]
# ### Data Analysis - US CAR ACCIDENT

# %% [markdown]
# #### Import Libraries

# %%
import pandas as pd
import numpy as np
import plotly_express as px
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.graph_objects as go
from plotly.subplots import make_subplots

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# #### Download Data

# %%
# !pip install kaggle

# %%
from google.colab import files
files.upload()

# %%
import os

os.makedirs('/root/.kaggle', exist_ok=True)

os.rename('kaggle.json', '/root/.kaggle/kaggle.json')

os.chmod('/root/.kaggle/kaggle.json', 600)

# %%
# !kaggle datasets download -d sobhanmoosavi/us-accidents

# %%
import zipfile

with zipfile.ZipFile("us-accidents.zip", "r") as zip_ref:
    zip_ref.extractall("data")

# %%
df = pd.read_csv("../input/us-accidents/US_Accidents_March23.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 df = pd.read_csv("../input/us-accidents/US_Accidents_March23.csv")
#
# File D:\ML PROJECTS\.venv\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %% [markdown]
# #### Data Understanding

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7728394 entries, 0 to 7728393
# Data columns (total 46 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   ID                     object
#  1   Source                 object
#  2   Severity               int64
#  3   Start_Time             object
#  4   End_Time               object
#  5   Start_Lat              float64
#  6   Start_Lng              float64
#  7   End_Lat                float64
#  8   End_Lng                float64
#  9   Distance(mi)           float64
#  10  Description            object
#  11  Street                 object
#  12  City                   object
#  13  County                 object
#  14  State                  object
#  15  Zipcode                object
#  16  Country                object
#  17  Timezone               object
#  18  Airport_Code           object
#  19  Weather_Timestamp      object
#  20  Temperature(F)         float64
# ...

# %%
df.describe()
# Out:
#            Severity     Start_Lat     Start_Lng       End_Lat       End_Lng  \
# count  7.728394e+06  7.728394e+06  7.728394e+06  4.325632e+06  4.325632e+06
# mean   2.212384e+00  3.620119e+01 -9.470255e+01  3.626183e+01 -9.572557e+01
# std    4.875313e-01  5.076079e+00  1.739176e+01  5.272905e+00  1.810793e+01
# min    1.000000e+00  2.455480e+01 -1.246238e+02  2.456601e+01 -1.245457e+02
# 25%    2.000000e+00  3.339963e+01 -1.172194e+02  3.346207e+01 -1.177543e+02
# 50%    2.000000e+00  3.582397e+01 -8.776662e+01  3.618349e+01 -8.802789e+01
# 75%    2.000000e+00  4.008496e+01 -8.035368e+01  4.017892e+01 -8.024709e+01
# max    4.000000e+00  4.900220e+01 -6.711317e+01  4.907500e+01 -6.710924e+01
#
#        Distance(mi)  Temperature(F)  Wind_Chill(F)   Humidity(%)  \
# count  7.728394e+06    7.564541e+06   5.729375e+06  7.554250e+06
# mean   5.618423e-01    6.166329e+01   5.825105e+01  6.483104e+01
# std    1.776811e+00    1.901365e+01   2.238983e+01  2.282097e+01
# ...

# %%
df.columns
# Out:
# Index(['ID', 'Source', 'Severity', 'Start_Time', 'End_Time', 'Start_Lat',
#        'Start_Lng', 'End_Lat', 'End_Lng', 'Distance(mi)', 'Description',
#        'Street', 'City', 'County', 'State', 'Zipcode', 'Country', 'Timezone',
#        'Airport_Code', 'Weather_Timestamp', 'Temperature(F)', 'Wind_Chill(F)',
#        'Humidity(%)', 'Pressure(in)', 'Visibility(mi)', 'Wind_Direction',
#        'Wind_Speed(mph)', 'Precipitation(in)', 'Weather_Condition', 'Amenity',
#        'Bump', 'Crossing', 'Give_Way', 'Junction', 'No_Exit', 'Railway',
#        'Roundabout', 'Station', 'Stop', 'Traffic_Calming', 'Traffic_Signal',
#        'Turning_Loop', 'Sunrise_Sunset', 'Civil_Twilight', 'Nautical_Twilight',
#        'Astronomical_Twilight'],
#       dtype='object')

# %%
df["City"].value_counts()
# Out:
# City
# Miami          186917
# Houston        169609
# Los Angeles    156491
# Charlotte      138652
# Dallas         130939
#                 ...
# Saint Croix         1
# Masardis            1
# Okaton              1
# Wasta               1
# Adell               1
# Name: count, Length: 13678, dtype: int64

# %% [markdown]
# ### Data Preprocessing

# %%
from sklearn.preprocessing import LabelEncoder

city_encoder = LabelEncoder()

df["City"] = city_encoder.fit_transform(df["City"].to_numpy())
df["City"] = df["City"].astype(np.uint16)

# %%
df = df.drop(columns=["ID", "Source", "Country", "Description"])

# %%
df["Start_Time"] = pd.to_datetime(df["Start_Time"].str[:19])
df["End_Time"] = pd.to_datetime(df["End_Time"].str[:19])

# %%
df["Timezone"] = df["Timezone"].map(
    {
        "US/Eastern": 0,
        "US/Pacific": 1,
        "US/Central": 2,
        "US/Mountain": 3
    }
)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7728394 entries, 0 to 7728393
# Data columns (total 42 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   Severity               uint8
#  1   Start_Time             datetime64[ns]
#  2   End_Time               datetime64[ns]
#  3   Start_Lat              float64
#  4   Start_Lng              float64
#  5   End_Lat                float64
#  6   End_Lng                float64
#  7   Distance(mi)           float64
#  8   Street                 object
#  9   City                   uint16
#  10  County                 object
#  11  State                  object
#  12  Zipcode                object
#  13  Timezone               float64
#  14  Airport_Code           object
#  15  Weather_Timestamp      object
#  16  Temperature(F)         float64
#  17  Wind_Chill(F)          float64
#  18  Humidity(%)            float64
#  19  Pressure(in)           float64
#  20  Visibility(mi)         float64
# ...

# %%
df["Severity"] = df["Severity"].astype(np.uint8)

# %%
df["Astronomical_Twilight"].value_counts()
# Out:
# Astronomical_Twilight
# Day      6377548
# Night    1327600
# Name: count, dtype: int64

# %%
for col in ["Sunrise_Sunset", "Civil_Twilight", "Nautical_Twilight", "Astronomical_Twilight"]:
  df[col] = (
    df[col]
    .map({"Night": 0, "Day": 1})
    .fillna(-1)
    .astype(np.int8)
)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7728394 entries, 0 to 7728393
# Data columns (total 42 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   Severity               uint8
#  1   Start_Time             datetime64[ns]
#  2   End_Time               datetime64[ns]
#  3   Start_Lat              float64
#  4   Start_Lng              float64
#  5   End_Lat                float64
#  6   End_Lng                float64
#  7   Distance(mi)           float64
#  8   Street                 object
#  9   City                   uint16
#  10  County                 object
#  11  State                  object
#  12  Zipcode                object
#  13  Timezone               float64
#  14  Airport_Code           object
#  15  Weather_Timestamp      object
#  16  Temperature(F)         float64
#  17  Wind_Chill(F)          float64
#  18  Humidity(%)            float64
#  19  Pressure(in)           float64
#  20  Visibility(mi)         float64
# ...

# %%
df["Wind_Direction"].value_counts()
# Out:
# Wind_Direction
# CALM        961624
# S           419989
# SSW         384840
# W           383913
# WNW         378781
# NW          369352
# Calm        368557
# SW          364470
# WSW         353806
# SSE         349110
# NNW         333427
# N           307151
# SE          294901
# E           278914
# ESE         268311
# NE          258639
# ENE         258474
# NNE         255311
# VAR         250566
# South       177375
# West        164751
# North       153385
# Variable    113996
# East        103545
# Name: count, dtype: int64

# %%
wind_encoder = LabelEncoder()

df["Wind_Direction"] = city_encoder.fit_transform(df["Wind_Direction"].to_numpy())
df["Wind_Direction"] = df["Wind_Direction"].astype(np.uint16)

# %%
for col in ['Distance(mi)',
       'Temperature(F)', 'Wind_Chill(F)', 'Humidity(%)', 'Pressure(in)',
       'Visibility(mi)', 'Wind_Speed(mph)', 'Precipitation(in)']:
  df[col] = df[col].astype(np.float16)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7728394 entries, 0 to 7728393
# Data columns (total 42 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   Severity               uint8
#  1   Start_Time             datetime64[ns]
#  2   End_Time               datetime64[ns]
#  3   Start_Lat              float64
#  4   Start_Lng              float64
#  5   End_Lat                float64
#  6   End_Lng                float64
#  7   Distance(mi)           float16
#  8   Street                 object
#  9   City                   uint16
#  10  County                 object
#  11  State                  object
#  12  Zipcode                object
#  13  Timezone               float64
#  14  Airport_Code           object
#  15  Weather_Timestamp      object
#  16  Temperature(F)         float16
#  17  Wind_Chill(F)          float16
#  18  Humidity(%)            float16
#  19  Pressure(in)           float16
#  20  Visibility(mi)         float16
# ...

# %%
df.to_csv("us_accidents.csv")

# %% [markdown]
# ### Data Visulization

# %% [markdown]
# #### Number of accidents in different states

# %%
state_counts = df["State"].value_counts()

fig = px.bar(
    x=state_counts.index,
    y=state_counts.values,
    labels={"x": "State", "y": "Number of accidents"},
    title="Number of accidents in different states"
)

fig.update_layout(xaxis_tickangle=-90)

fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #### Top 10 States with the Highest Number of Accidents

# %%
state_counts = df["State"].value_counts().head(10)

fig = px.bar(
    x=state_counts.values,
    y=state_counts.index,
    orientation="h",
    color=state_counts.values,
    color_continuous_scale="Viridis",
    labels={"x": "Number of Accidents", "y": "State"},
    title="Top 10 States with the Highest Number of Accidents"
)

fig.update_layout(
    yaxis=dict(categoryorder="total ascending")
)

fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #### 5 Top Weather Conditions for Accidents

# %%
weather_counts = df['Weather_Condition'].value_counts().head(5)

fig = px.bar(
    x=weather_counts.index,
    y=weather_counts.values,
    labels={"x": "Weather Condition", "y": "Number of Accidents"},
    title="5 Top Weather Conditions for Accidents"
)

fig.update_layout(
    xaxis_tickangle=-90
)

fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #### Count of Severity

# %%
severity_counts = df['Severity'].value_counts()

fig = make_subplots(
    rows=1, cols=2,
    specs=[[{"type": "domain"}, {"type": "xy"}]],
    subplot_titles=("Percentage Severity Distribution", "Count of Severity")
)

fig.add_trace(
    go.Pie(
        labels=severity_counts.index,
        values=severity_counts.values,
        hole=0,
    ),
    row=1, col=1
)


fig.add_trace(
    go.Bar(
        x=severity_counts.index,
        y=severity_counts.values
    ),
    row=1, col=2
)

fig.update_layout(
    title_text="Severity Analysis",
    showlegend=False
)

fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ####  Medium distance by severity

# %%
severity_distance = (
    df.groupby("Severity")["Distance(mi)"]
    .mean()
    .sort_values(ascending=False)
)

fig = px.bar(
    x=severity_distance.values,
    y=severity_distance.index,
    orientation="h",
    color=severity_distance.values,
    color_continuous_scale="Viridis",
    labels={
        "x": "Distance (mi)",
        "y": "Severity"
    },
    title="Mean distance by severity"
)

fig.update_layout(
    yaxis=dict(categoryorder="total ascending")
)

fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ####  Number of accidents for weekday

# %%
df['Start_Time'] = pd.to_datetime(df['Start_Time'])

counts = df['Start_Time'].dt.day_name().value_counts()

weekdays = ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"]

counts = counts.reindex(weekdays)

fig = px.bar(
    x=counts.index,
    y=counts.values,
    color=counts.values,
    color_continuous_scale="Viridis",
    labels={
        "x": "Weekday",
        "y": "Number of Accidents"
    },
    title="Number of accidents for each weekday"
)

fig.update_layout(
    xaxis_tickangle=-45
)

fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df_num = df[['Temperature(F)', 'Wind_Chill(F)', 'Humidity(%)', 'Severity',
             'Start_Lng', 'End_Lng', 'Start_Lat', 'End_Lat',
             'Distance(mi)', 'Pressure(in)', 'Visibility(mi)',
             'Wind_Speed(mph)', 'Precipitation(in)']]

corr = df_num.corr()

fig = px.imshow(
    corr,
    text_auto=".2f",
    color_continuous_scale="RdBu_r",
    zmin=-1,
    zmax=1,
    aspect="auto",
    title="Correlation Heatmap"
)

fig.update_layout(
    width=900,
    height=800
)

fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ####  Severity by Fog, Light Rain, Rain, Heavy Rain and Snow

# %%
weather_conditions = ["Fog", "Light Rain", "Rain", "Heavy Rain", "Snow"]

for s in weather_conditions:

    filtered = df[df["Weather_Condition"] == s]["Severity"].value_counts()

    fig = make_subplots(
        rows=1, cols=2,
        specs=[[{"type": "xy"}, {"type": "domain"}]],
        subplot_titles=("Severity Count", "Severity Percentage")
    )


    fig.add_trace(
        go.Bar(
            x=filtered.index,
            y=filtered.values,
            marker_color="gold",
            name="Count"
        ),
        row=1, col=1
    )


    fig.add_trace(
        go.Pie(
            labels=filtered.index,
            values=filtered.values,
            textinfo="percent+label"
        ),
        row=1, col=2
    )

    fig.update_layout(
        title_text=f"Accident Severity Under {s}",
        showlegend=False
    )

    fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
features = [
    'Bump', 'Crossing', 'Give_Way', 'Junction', 'No_Exit',
    'Railway', 'Roundabout', 'Station', 'Stop',
    'Traffic_Calming', 'Traffic_Signal', 'Turning_Loop'
]

for s in features:


    if s in df.columns and df[s].sum() > 0:

        severity_counts = df[df[s] == True]['Severity'].value_counts()

        fig = make_subplots(
            rows=1, cols=2,
            specs=[[{"type": "xy"}, {"type": "domain"}]],
            subplot_titles=("Severity Count", "Severity Percentage")
        )


        fig.add_trace(
            go.Bar(
                x=severity_counts.index,
                y=severity_counts.values,
                marker_color="gold"
            ),
            row=1, col=1
        )


        fig.add_trace(
            go.Pie(
                labels=severity_counts.index,
                values=severity_counts.values,
                textinfo="percent+label"
            ),
            row=1, col=2
        )

        fig.update_layout(
            title=f"Accident Severity Near {s}",
            showlegend=False
        )

        fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #### Accident Location Distribution

# %%
import plotly.express as px
import plotly.io as pio

pio.renderers.default = "notebook_connected"

df_clean = df.dropna(subset=["Start_Lat", "Start_Lng"]).sample(500000, random_state=42)

df_clean["Start_Lat"] = df_clean["Start_Lat"].round(2)
df_clean["Start_Lng"] = df_clean["Start_Lng"].round(2)

fig = px.scatter_mapbox(
    df_clean,
    lat="Start_Lat",
    lon="Start_Lng",
    color="Severity",
    opacity=0.3,
    zoom=4,
    mapbox_style="open-street-map",
    title="Accident Locations (Optimized)"
)

fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.3.1.min"</script>
